# %% [markdown]
# # Demographic_Data_Analyser

# %% [markdown]
# ## This is a project from FreeCodeCamp to analyse a certain demographic to obtain crucial information about the demographic.

# %% [markdown]
# ### First step is importing important libraries which will be used.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### We then load the data to see what we're working with.

# %%
df = pd.read_csv('adult.data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num
# 0       39         State-gov   77516   Bachelors             13  \
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex
# 0           Never-married       Adm-clerical  Not-in-family  White    Male  \
# ...

# %% [markdown]
# ### Seeing general info about the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Before we continue we must ensure our data has no missing values, duplicates, wrong data types and outliers.
# ### Essentially we must ensure our data is clean.

# %% [markdown]
# ### From the info above in df.info() we can see that this dataset with no missing values.

# %% [markdown]
# ### We now want to check for duplicates.

# %%
df[df.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  education-num
# 4881    25           Private  308144     Bachelors             13  \
# 5104    90           Private   52386  Some-college             10
# 9171    21           Private  250051  Some-college             10
# 11631   20           Private  107658  Some-college             10
# 13084   25           Private  195994       1st-4th              2
# 15059   21           Private  243368     Preschool              1
# 17040   46           Private  173243       HS-grad              9
# 18555   30           Private  144593       HS-grad              9
# 18698   19           Private   97261       HS-grad              9
# 21318   19           Private  138153  Some-college             10
# 21490   19           Private  146679  Some-college             10
# 21875   49           Private   31267       7th-8th              4
# 22300   25           Private  195994       1st-4th              2
# ...

# %%
# Since its possible for many people in a demographic to have similar stats we shall not remove duplicates.

# %% [markdown]
# ### For the numeric columns in the DataFrame we shall not remove outliers as for all numeric columns since the values may vary greatly from one person to another in a huge demographic.
# ### It is therefore not fair to only use people who are in a specific range of values.

# %% [markdown]
# ### We now want to check for wrong datatypes.

# %%
# First we want to check which are the columns in our dataframe.
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
# For each of these columns we want to check if there are wrong datatypes.
# The first step is to check the dtypes of each column in the dataframe.
df['age'].dtypes
# Out:
# dtype('int64')

# %%
# Now that we know the dtypes of each column we can wrote a loop that checks for each column if there are wrong datatypes.
# First step is to create a dictionary mapping the the dtype to the type of an indiviual value in the column.
value_types = {
    'int64' : int,
    'object' : str,
    'float64' : float
}
value_types
# Out:
# {'int64': int, 'object': str, 'float64': float}

# %%
# We then use a for loop for all the columns to use this mapping to check wrong types.
# We then put the columns in a dictionary with a mapping of a list that says if each column in the dictionary contains a wrong data type.
wrong_data_types = {}
for column in df.columns:
    wrong_data_types[column] = [x for x in df[column] if type(x) != value_types[str(df[column].dtypes)]]

wrong_data_types
# Out:
# {'age': [],
#  'workclass': [],
#  'fnlwgt': [],
#  'education': [],
#  'education-num': [],
#  'marital-status': [],
#  'occupation': [],
#  'relationship': [],
#  'race': [],
#  'sex': [],
#  'capital-gain': [],
#  'capital-loss': [],
#  'hours-per-week': [],
#  'native-country': [],
#  'salary': []}

# %% [markdown]
# ### No wrong datatypes in any of of the columns.
# ### This means our data is clean and we can begin analysis.

# %% [markdown]
# ## Exploratory Data Analysis.

# %% [markdown]
# ### We shall then use our clean data to answer crucial questions about a demographic.

# %% [markdown]
# #### Question 1: How many people of each race are represented in this dataset?

# %%
# First of all checking info on our dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# We see there's a race column hence we can use the value_counts() function on the column to see how many times each value occurs.
df['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
# The cell above answers our question.

# %% [markdown]
# #### Question 2: What is the average age of men in our database?

# %%
# First we look at our dataframe
df
# Out:
#        age         workclass  fnlwgt   education  education-num
# 0       39         State-gov   77516   Bachelors             13  \
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex
# 0           Never-married       Adm-clerical  Not-in-family  White    Male  \
# ...

# %%
# We then isolate the dataframe to include only men.
men_in_dataframe = df[df['sex'] == 'Male']
men_in_dataframe
# Out:
#        age         workclass  fnlwgt     education  education-num
# 0       39         State-gov   77516     Bachelors             13  \
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32553   32           Private  116138       Masters             14
# 32554   53           Private  321865       Masters             14
# 32555   22           Private  310152  Some-college             10
# 32557   40           Private  154374       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
#
#            marital-status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family  \
# ...

# %%
# We then find the average of the age column in our new dataframe?
print('The average age of men in our database is', men_in_dataframe['age'].mean())
# Out:
# The average age of men in our database is 39.43354749885268

# %% [markdown]
# #### Question 3: What is the percentage of people with Bachelor's Degree?

# %%
# First of all looking at our dataframe?
df
# Out:
#        age         workclass  fnlwgt   education  education-num
# 0       39         State-gov   77516   Bachelors             13  \
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex
# 0           Never-married       Adm-clerical  Not-in-family  White    Male  \
# ...

# %%
# Isolating the bachelors in education
bachelors = df['education'][df['education'] == 'Bachelors']

print('The percentage of people with Bachelors education is', (len(bachelors) / len(df['education']))*100)
# Out:
# The percentage of people with Bachelors education is 16.44605509658794

# %% [markdown]
# #### Question 4: What is the percentage of people with higher education (Bachelor's, Masters or Doctorate) that make >50K?

# %%
# Seeing the dataframe
df
# Out:
#        age         workclass  fnlwgt   education  education-num
# 0       39         State-gov   77516   Bachelors             13  \
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex
# 0           Never-married       Adm-clerical  Not-in-family  White    Male  \
# ...

# %%
# Filtering out relevant information
df_filtered = df[(df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])) & (df['salary'] == '>50K')]

# %%
# Getting the percentage
percentage = (len(df_filtered) / len(df[df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])])) * 100

print('The percentage of people with higher education that earn more than 50K is', percentage)
# Out:
# The percentage of people with higher education that earn more than 50K is 46.535843011613935
